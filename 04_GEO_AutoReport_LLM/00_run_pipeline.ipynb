# %%
# GEO RNA-seq Auto-Analysis Pipeline 
# By: Ishjamts Ravdandorj
# Purpose:
# - Load raw *HUMAN* RNA-seq count data (GEO)
# - Perform QC, normalisation, PCA, and differential expression
# - Produce structured outputs for automated LLM-based reporting (API)

import pandas as pd
import pandas as pd
import numpy as np
from pathlib import Path
